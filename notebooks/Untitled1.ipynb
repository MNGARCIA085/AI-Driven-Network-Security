# %%
import pandas as pd

# %%
df = pd.read_csv("../data/output2.csv")

# %%
df.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 80           87077                   3
# 1                 53           84331                   2
# 2                443         7403457                  20
# 3                443               3                   2
# 4                 53             350                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        6                           26
# 1                        2                           68
# 2                       20                         1082
# 3                        0                           12
# 4                        2                           94
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                         11607                      20
# 1                           346                      34
# 2                         27061                     369
# ...

# %%
# Remove leading/trailing spaces from all column names
df.columns = df.columns.str.strip()

# %%
# remove extra rare cases
# Keep only classes with >= 2 samples


df_sample = df

counts = df_sample['Label'].value_counts()
valid_classes = counts[counts >= 2].index
df_sample = df_sample[df_sample['Label'].isin(valid_classes)]


"""
or combine rare attacks into rare attacks
rare_threshold = 50  # or choose small number
counts = df_sample['Label'].value_counts()
rare_classes = counts[counts < rare_threshold].index

df_sample['Label'] = df_sample['Label'].replace(rare_classes, 'Other_Attack')
"""
# Out:
# "\nor combine rare attacks into rare attacks\nrare_threshold = 50  # or choose small number\ncounts = df_sample['Label'].value_counts()\nrare_classes = counts[counts < rare_threshold].index\n\ndf_sample['Label'] = df_sample['Label'].replace(rare_classes, 'Other_Attack')\n"

# %%
df.shape
# Out:
# (100000, 79)

# %%
# separate in train/val df and test df
from sklearn.model_selection import train_test_split


data = df_sample


# Suppose df_sample has 100k rows
train_val_df, test_df = train_test_split(
    data,
    test_size=0.2,  # 20% for test
    stratify=data['Label'],
    random_state=42
)

# %%
train_val_data = train_val_df.to_csv('../data/train_val_data.csv', index=False)

# %%
test_data = test_df.to_csv('../data/test_data.csv', index=False)
